# %% [markdown]
# # Exploration des différents modèles (pour la classification des vitesses sans PCA)
#
# L'idée de ce notebook est de faire une exploration rapide de différents modèles pour conserver les plus prometteurs et de les étudier plus précisément ensuite.
#
# ### Modèles étudiés
# - **Random Forest**
# - **Gradient Boosting**
# - **SVM**
# - **KNN**
# - **Régression Linéaire, Logistique ...**
# - **ANN** (Keras)

# %% [markdown]
# ### Récupération des données

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.utils import shuffle

data = pd.read_csv('../preprocessing_data/speed_preprocess.csv')

X = data.drop('vitesse', axis=1)
y = data['vitesse']

le = LabelEncoder()
y = le.fit_transform(y)

X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

# %% [markdown]
# Comme cette étape ne concerne que l'exploration des résultats des différents modèles, on se passe de séparer les données en validation et d'entraînement pour l'instant, on va juste faire une validation croisée.

# %% [markdown]
# ### Exploration des différents modèles

# %%
from explore_models import explore_models

top3, best_model = explore_models(X_shuffled, y_shuffled)
# Out:
# Training Random Forest...
# -> Random Forest result: [0.97402597 0.96536797 0.98695652 0.97826087 0.9826087 ]
# Training Gradient Boosting...
# -> Gradient Boosting result: [0.96969697 0.97402597 0.98695652 0.97826087 0.9826087 ]
# Training SVM Linear...
# -> SVM Linear result: [0.8961039  0.88311688 0.89565217 0.92173913 0.93478261]
# Training SVM RBF...
# -> SVM RBF result: [0.88311688 0.85714286 0.8826087  0.89565217 0.90434783]
# Training SVM Poly...
# -> SVM Poly result: [0.90909091 0.8961039  0.91304348 0.93043478 0.93913043]
# Training SVM Sigmoid...
# -> SVM Sigmoid result: [0.6017316  0.54545455 0.6        0.60434783 0.63043478]
# Training KNN...
# -> KNN result: [0.96969697 0.96969697 0.96086957 0.96086957 0.95217391]
# Training KNN Cosine...
# -> KNN Cosine result: [0.96103896 0.995671   0.97826087 0.9826087  0.96956522]
# Training Logistic Regression...
# -> Logistic Regression result: [0.87012987 0.84848485 0.86086957 0.88695652 0.89130435]
# Training SGD Classifier...
# -> SGD Classifier result: [0.63203463 0.8008658  0.85217391 0.65652174 0.86086957]
# Training ANN...
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B5745367A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B5745367A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -> ANN result: [0.76623377 0.74891775 0.83043478 0.76521739 0.82608696]
# === Moyenne et écart-type des scores ===
# Random Forest: mean = 0.9774, std = 0.0074
# Gradient Boosting: mean = 0.9783, std = 0.0061
# SVM Linear: mean = 0.9063, std = 0.0190
# SVM RBF: mean = 0.8846, std = 0.0160
# SVM Poly: mean = 0.9176, std = 0.0154
# SVM Sigmoid: mean = 0.5964, std = 0.0278
# KNN: mean = 0.9627, std = 0.0066
# KNN Cosine: mean = 0.9774, std = 0.0118
# Logistic Regression: mean = 0.8715, std = 0.0160
# SGD Classifier: mean = 0.7605, std = 0.0974
# ANN: mean = 0.7874, std = 0.0340
#
# === Top 3 modèles (détail des scores) ===
# Gradient Boosting: scores = [0.96969697 0.97402597 0.98695652 0.97826087 0.9826087 ]
#
# Modèle: Gradient Boosting
# Random Forest: scores = [0.97402597 0.96536797 0.98695652 0.97826087 0.9826087 ]
#
# Modèle: Random Forest
# KNN Cosine: scores = [0.96103896 0.995671   0.97826087 0.9826087  0.96956522]
#
# Modèle: KNN Cosine
# === Random Forest Feature Importances ===
# 1. Feature 6: 0.1280
# 2. Feature 10: 0.1034
# 3. Feature 4: 0.1026
# 4. Feature 14: 0.0827
# 5. Feature 2: 0.0758
#
# === Gradient Boosting Feature Importances ===
# 1. Feature 8: 0.3589
# 2. Feature 6: 0.3130
# 3. Feature 14: 0.0548
# 4. Feature 10: 0.0435
# 5. Feature 20: 0.0278

# %% [markdown]
# ### Download the best model (temporary)

# %%
import joblib

joblib.dump(best_model, '../models_temp/best_model_speed.pkl')
# Out:
# ['../models_temp/best_model_speed.pkl']
