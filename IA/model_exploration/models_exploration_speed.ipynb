# %% [markdown]
# # Exploration des différents modèles (pour la classification des vitesses sans PCA)
#
# L'idée de ce notebook est de faire une exploration rapide de différents modèles pour conserver les plus prometteurs et de les étudier plus précisément ensuite.
#
# ### Modèles étudiés
# - **Random Forest**
# - **Gradient Boosting**
# - **SVM**
# - **KNN**
# - **Régression Linéaire, Logistique ...**
# - **ANN** (Keras)

# %% [markdown]
# ### Récupération des données

# %%
import pandas as pd
from sklearn.utils import shuffle

data = pd.read_csv('../preprocessing_data/speed_preprocess.csv')

X = data.drop('vitesse', axis=1)
y = data['vitesse']

X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

# %% [markdown]
# Comme cette étape ne concerne que l'exploration des résultats des différents modèles, on se passe de séparer les données en validation et d'entraînement pour l'instant, on va juste faire une validation croisée.

# %% [markdown]
# ### Exploration des différents modèles

# %%
from explore_models import explore_models

top3, best_model = explore_models(X_shuffled, y_shuffled)
# Out:
# Training Random Forest...
# -> Random Forest result: [0.97835498 0.96969697 0.9826087  0.96521739 0.96956522]
# Training Gradient Boosting...
# -> Gradient Boosting result: [0.98268398 0.97402597 0.98695652 0.96086957 0.96956522]
# Training SVM Linear...
# -> SVM Linear result: [0.89177489 0.91341991 0.92173913 0.87391304 0.9173913 ]
# Training SVM RBF...
# -> SVM RBF result: [0.88311688 0.89177489 0.9        0.84347826 0.89130435]
# Training SVM Poly...
# -> SVM Poly result: [0.91774892 0.91341991 0.94347826 0.87391304 0.92608696]
# Training SVM Sigmoid...
# -> SVM Sigmoid result: [0.58874459 0.61904762 0.6173913  0.6        0.62173913]
# Training KNN...
# -> KNN result: [0.97402597 0.96103896 0.95652174 0.95217391 0.97391304]
# Training KNN Cosine...
# -> KNN Cosine result: [0.98701299 0.96969697 0.98695652 0.97391304 0.96956522]
# Training Logistic Regression...
# -> Logistic Regression result: [0.83982684 0.86147186 0.9        0.84347826 0.8826087 ]
# Training SGD Classifier...
# -> SGD Classifier result: [0.70562771 0.7965368  0.73478261 0.80869565 0.79565217]
# Training ANN...
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024E4A862480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024E4A862480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -> ANN result: [0.80519481 0.84848485 0.87826087 0.8        0.70869565]
# === Moyenne et écart-type des scores ===
# Random Forest: mean = 0.9731, std = 0.0064
# Gradient Boosting: mean = 0.9748, std = 0.0093
# SVM Linear: mean = 0.9036, std = 0.0181
# SVM RBF: mean = 0.8819, std = 0.0200
# SVM Poly: mean = 0.9149, std = 0.0229
# SVM Sigmoid: mean = 0.6094, std = 0.0128
# KNN: mean = 0.9635, std = 0.0090
# KNN Cosine: mean = 0.9774, std = 0.0080
# Logistic Regression: mean = 0.8655, std = 0.0230
# SGD Classifier: mean = 0.7683, std = 0.0406
# ANN: mean = 0.8081, std = 0.0575
#
# === Top 3 modèles (détail des scores) ===
# KNN Cosine: scores = [0.98701299 0.96969697 0.98695652 0.97391304 0.96956522]
#
# Modèle: KNN Cosine
# Gradient Boosting: scores = [0.98268398 0.97402597 0.98695652 0.96086957 0.96956522]
#
# Modèle: Gradient Boosting
# Random Forest: scores = [0.97835498 0.96969697 0.9826087  0.96521739 0.96956522]
#
# Modèle: Random Forest
# === Random Forest Feature Importances ===
# 1. Feature 4: 0.1438
# 2. Feature 6: 0.1146
# 3. Feature 8: 0.0920
# 4. Feature 14: 0.0824
# 5. Feature 10: 0.0737
#
# === Gradient Boosting Feature Importances ===
# 1. Feature 4: 0.5701
# 2. Feature 8: 0.1579
# 3. Feature 14: 0.0402
# 4. Feature 16: 0.0263
# 5. Feature 13: 0.0223

# %% [markdown]
# ### Download the best model (temporary)

# %%
import joblib

joblib.dump(best_model, '../models_temp/best_model_speed.pkl')
# Out:
# ['../models_temp/best_model_speed.pkl']
