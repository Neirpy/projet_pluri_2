# %% [markdown]
# # Exploration des différents modèles (pour la classification des déplacements avec PCA)
#
# L'idée de ce notebook est de faire une exploration rapide de différents modèles pour conserver les plus prometteurs et de les étudier plus précisément ensuite.
#
# ### Modèles étudiés
# - **Random Forest**
# - **Gradient Boosting**
# - **SVM**
# - **KNN**
# - **Régression Linéaire, Logistique ...**
# - **ANN** (Keras)

# %% [markdown]
# ### Récupération des données

# %%
import pandas as pd
from sklearn.utils import shuffle

data = pd.read_csv('../preprocessing_data/move_preprocess_pca.csv')

X = data.drop('action', axis=1)
y = data['action']

X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

# %% [markdown]
# Comme cette étape ne concerne que l'exploration des résultats des différents modèles, on se passe de séparer les données en validation et d'entraînement pour l'instant, on va juste faire une validation croisée.

# %% [markdown]
# ### Exploration des différents modèles

# %%
from explore_models import explore_models

top3, best_model = explore_models(X_shuffled, y_shuffled)
# Out:
# Training Random Forest...
# -> Random Forest result: [0.98783784 0.99189189 0.98918919 0.99054054 0.98783784]
# Training Gradient Boosting...
# -> Gradient Boosting result: [0.98378378 0.98378378 0.98243243 0.98783784 0.97702703]
# Training SVM Linear...
# -> SVM Linear result: [0.93783784 0.9527027  0.95675676 0.9527027  0.94189189]
# Training SVM RBF...
# -> SVM RBF result: [0.96216216 0.95945946 0.96351351 0.96081081 0.94594595]
# Training SVM Poly...
# -> SVM Poly result: [0.92297297 0.92297297 0.92702703 0.91216216 0.93108108]
# Training SVM Sigmoid...
# -> SVM Sigmoid result: [0.68513514 0.67972973 0.68918919 0.66891892 0.69189189]
# Training KNN...
# -> KNN result: [0.97837838 0.97432432 0.98378378 0.97162162 0.97027027]
# Training KNN Cosine...
# -> KNN Cosine result: [0.95540541 0.96486486 0.95810811 0.96891892 0.94189189]
# Training Logistic Regression...
# -> Logistic Regression result: [0.92837838 0.93108108 0.94459459 0.93918919 0.92972973]
# Training SGD Classifier...
# -> SGD Classifier result: [0.86351351 0.87702703 0.88378378 0.8472973  0.88783784]
# Training ANN...
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B0823AECA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B0867CE980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -> ANN result: [0.87027027 0.93378378 0.93378378 0.93783784 0.89864865]
# === Moyenne et écart-type des scores ===
# Random Forest: mean = 0.9895, std = 0.0016
# Gradient Boosting: mean = 0.9830, std = 0.0035
# SVM Linear: mean = 0.9484, std = 0.0072
# SVM RBF: mean = 0.9584, std = 0.0064
# SVM Poly: mean = 0.9232, std = 0.0063
# SVM Sigmoid: mean = 0.6830, std = 0.0081
# KNN: mean = 0.9757, std = 0.0049
# KNN Cosine: mean = 0.9578, std = 0.0093
# Logistic Regression: mean = 0.9346, std = 0.0063
# SGD Classifier: mean = 0.8719, std = 0.0148
# ANN: mean = 0.9149, std = 0.0264
#
# === Top 3 modèles (détail des scores) ===
# Random Forest: scores = [0.98783784 0.99189189 0.98918919 0.99054054 0.98783784]
#
# Modèle: Random Forest
# Gradient Boosting: scores = [0.98378378 0.98378378 0.98243243 0.98783784 0.97702703]
#
# Modèle: Gradient Boosting
# KNN: scores = [0.97837838 0.97432432 0.98378378 0.97162162 0.97027027]
#
# Modèle: KNN
# === Random Forest Feature Importances ===
# 1. Feature 1: 0.3790
# 2. Feature 2: 0.3329
# 3. Feature 0: 0.2881
#
# === Gradient Boosting Feature Importances ===
# 1. Feature 2: 0.4244
# 2. Feature 1: 0.3467
# 3. Feature 0: 0.2289

# %% [markdown]
# # Dowload the best model (temporary)

# %%
import joblib

joblib.dump(best_model, '../models_temp/best_model_move_pca.pkl')
# Out:
# ['../models_temp/best_model_move_pca.pkl']
