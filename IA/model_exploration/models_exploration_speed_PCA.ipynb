# %% [markdown]
# # Exploration des différents modèles (pour la classification des vitesses avec PCA)
#
# L'idée de ce notebook est de faire une exploration rapide de différents modèles pour conserver les plus prometteurs et de les étudier plus précisément ensuite.
#
# ### Modèles étudiés
# - **Random Forest**
# - **Gradient Boosting**
# - **SVM**
# - **KNN**
# - **Régression Linéaire, Logistique ...**
# - **ANN** (Keras)

# %% [markdown]
# ### Récupération des données

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.utils import shuffle

data = pd.read_csv('../preprocessing_data/speed_preprocess_pca.csv')

X = data.drop('vitesse', axis=1)
y = data['vitesse']

le = LabelEncoder()
y = le.fit_transform(y)

X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

# %% [markdown]
# Comme cette étape ne concerne que l'exploration des résultats des différents modèles, on se passe de séparer les données en validation et d'entraînement pour l'instant, on va juste faire une validation croisée.

# %% [markdown]
# ### Exploration des différents modèles

# %%
from explore_models import explore_models

top3, best_model = explore_models(X_shuffled, y_shuffled)
# Out:
# Training Random Forest...
# -> Random Forest result: [0.93506494 0.8961039  0.90869565 0.92173913 0.93913043]
# Training Gradient Boosting...
# -> Gradient Boosting result: [0.89177489 0.86147186 0.89130435 0.90434783 0.93043478]
# Training SVM Linear...
# -> SVM Linear result: [0.87012987 0.84848485 0.86956522 0.86086957 0.87391304]
# Training SVM RBF...
# -> SVM RBF result: [0.85281385 0.83116883 0.8826087  0.85652174 0.86956522]
# Training SVM Poly...
# -> SVM Poly result: [0.77489177 0.78787879 0.77391304 0.79130435 0.8173913 ]
# Training SVM Sigmoid...
# -> SVM Sigmoid result: [0.63203463 0.61471861 0.6826087  0.69565217 0.65652174]
# Training KNN...
# -> KNN result: [0.85714286 0.83549784 0.84347826 0.86521739 0.86956522]
# Training KNN Cosine...
# -> KNN Cosine result: [0.77922078 0.75757576 0.77826087 0.76956522 0.8       ]
# Training Logistic Regression...
# -> Logistic Regression result: [0.82683983 0.78354978 0.80434783 0.82608696 0.86521739]
# Training SGD Classifier...
# -> SGD Classifier result: [0.81385281 0.75324675 0.7826087  0.82173913 0.82173913]
# Training ANN...
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000159D9933100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000159D9933100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -> ANN result: [0.82251082 0.80952381 0.80434783 0.83478261 0.86956522]
# === Moyenne et écart-type des scores ===
# Random Forest: mean = 0.9201, std = 0.0161
# Gradient Boosting: mean = 0.8959, std = 0.0223
# SVM Linear: mean = 0.8646, std = 0.0091
# SVM RBF: mean = 0.8585, std = 0.0172
# SVM Poly: mean = 0.7891, std = 0.0157
# SVM Sigmoid: mean = 0.6563, std = 0.0302
# KNN: mean = 0.8542, std = 0.0129
# KNN Cosine: mean = 0.7769, std = 0.0139
# Logistic Regression: mean = 0.8212, std = 0.0272
# SGD Classifier: mean = 0.7986, std = 0.0269
# ANN: mean = 0.8281, std = 0.0233
#
# === Top 3 modèles (détail des scores) ===
# Random Forest: scores = [0.93506494 0.8961039  0.90869565 0.92173913 0.93913043]
#
# Modèle: Random Forest
# Gradient Boosting: scores = [0.89177489 0.86147186 0.89130435 0.90434783 0.93043478]
#
# Modèle: Gradient Boosting
# SVM Linear: scores = [0.87012987 0.84848485 0.86956522 0.86086957 0.87391304]
#
# Modèle: SVM Linear
# === Random Forest Feature Importances ===
# 1. Feature 0: 0.7832
# 2. Feature 1: 0.2168
#
# === Gradient Boosting Feature Importances ===
# 1. Feature 0: 0.8881
# 2. Feature 1: 0.1119

# %% [markdown]
# ### Download the best model (temporary)

# %%
import joblib

joblib.dump(best_model, '../models_temp/best_model_speed_pca.pkl')
# Out:
# ['../models_temp/best_model_speed_pca.pkl']
