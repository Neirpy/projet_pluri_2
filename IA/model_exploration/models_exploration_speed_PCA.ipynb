# %% [markdown]
# # Exploration des différents modèles (pour la classification des vitesses avec PCA)
#
# L'idée de ce notebook est de faire une exploration rapide de différents modèles pour conserver les plus prometteurs et de les étudier plus précisément ensuite.
#
# ### Modèles étudiés
# - **Random Forest**
# - **Gradient Boosting**
# - **SVM**
# - **KNN**
# - **Régression Linéaire, Logistique ...**
# - **ANN** (Keras)

# %% [markdown]
# ### Récupération des données

# %%
import pandas as pd
from sklearn.utils import shuffle

data = pd.read_csv('../preprocessing_data/speed_preprocess_pca.csv')

X = data.drop('vitesse', axis=1)
y = data['vitesse']

X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

# %% [markdown]
# Comme cette étape ne concerne que l'exploration des résultats des différents modèles, on se passe de séparer les données en validation et d'entraînement pour l'instant, on va juste faire une validation croisée.

# %% [markdown]
# ### Exploration des différents modèles

# %%
from explore_models import explore_models

top3, best_model = explore_models(X_shuffled, y_shuffled)
# Out:
# Training Random Forest...
# -> Random Forest result: [0.88311688 0.9047619  0.9173913  0.90434783 0.91304348]
# Training Gradient Boosting...
# -> Gradient Boosting result: [0.8961039  0.9047619  0.89565217 0.86521739 0.89565217]
# Training SVM Linear...
# -> SVM Linear result: [0.82683983 0.86580087 0.87391304 0.83043478 0.88695652]
# Training SVM RBF...
# -> SVM RBF result: [0.83549784 0.87878788 0.88695652 0.82608696 0.88695652]
# Training SVM Poly...
# -> SVM Poly result: [0.7965368  0.81385281 0.83478261 0.77391304 0.79565217]
# Training SVM Sigmoid...
# -> SVM Sigmoid result: [0.5974026  0.67965368 0.64782609 0.63913043 0.64347826]
# Training KNN...
# -> KNN result: [0.82683983 0.84415584 0.86956522 0.83478261 0.8826087 ]
# Training KNN Cosine...
# -> KNN Cosine result: [0.77489177 0.84415584 0.78695652 0.81304348 0.81304348]
# Training Logistic Regression...
# -> Logistic Regression result: [0.80519481 0.81818182 0.83043478 0.82608696 0.84782609]
# Training SGD Classifier...
# -> SGD Classifier result: [0.73160173 0.77922078 0.75217391 0.80434783 0.72608696]
# Training ANN...
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000017498AB2DE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000017498AB2DE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -> ANN result: [0.82251082 0.81818182 0.86086957 0.83043478 0.85217391]
# === Moyenne et écart-type des scores ===
# Random Forest: mean = 0.9045, std = 0.0118
# Gradient Boosting: mean = 0.8915, std = 0.0136
# SVM Linear: mean = 0.8568, std = 0.0240
# SVM RBF: mean = 0.8629, std = 0.0265
# SVM Poly: mean = 0.8029, std = 0.0203
# SVM Sigmoid: mean = 0.6415, std = 0.0263
# KNN: mean = 0.8516, std = 0.0211
# KNN Cosine: mean = 0.8064, std = 0.0240
# Logistic Regression: mean = 0.8255, std = 0.0141
# SGD Classifier: mean = 0.7587, std = 0.0295
# ANN: mean = 0.8368, std = 0.0168
#
# === Top 3 modèles (détail des scores) ===
# Random Forest: scores = [0.88311688 0.9047619  0.9173913  0.90434783 0.91304348]
#
# Modèle: Random Forest
# Gradient Boosting: scores = [0.8961039  0.9047619  0.89565217 0.86521739 0.89565217]
#
# Modèle: Gradient Boosting
# SVM RBF: scores = [0.83549784 0.87878788 0.88695652 0.82608696 0.88695652]
#
# Modèle: SVM RBF
# === Random Forest Feature Importances ===
# 1. Feature 0: 0.7575
# 2. Feature 1: 0.2425
#
# === Gradient Boosting Feature Importances ===
# 1. Feature 0: 0.8813
# 2. Feature 1: 0.1187

# %% [markdown]
# ### Download the best model (temporary)

# %%
import joblib

joblib.dump(best_model, '../models_temp/best_model_speed_pca.pkl')
# Out:
# ['../models_temp/best_model_speed_pca.pkl']
