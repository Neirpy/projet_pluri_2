# %% [markdown]
# # Preprocessing
#
# ## Imports

# %%
from IA.exploration_data.concat import *
from IA.exploration_data.preprocessing import *
import pandas as pd

# %% [markdown]
# ## Création des dataframes

# %%
df_move, df_speed = find_all_from_directory()

# %% [markdown]
# ## Rapide observation des datasets
#
# ### Shapes

# %%
df_move.shape
# Out:
# (925, 69)

# %%
df_speed.shape
# Out:
# (288, 69)

# %% [markdown]
# ### Summary

# %%
df_move.sample(10)
# Out:
#      Unnamed: 0    NOSE_X    NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# 807         807  0.446584  0.227496          0.458257          0.211302
# 206         206  0.549353  0.168465          0.557696          0.150743
# 61           61  0.518800  0.171750          0.524346          0.153296
# 168         168  0.517559  0.252314          0.529777          0.228308
# 423         423  0.533224  0.304335          0.541050          0.291746
# 120         120  0.548816  0.281889          0.560593          0.263677
# 757         757  0.516249  0.242233          0.528882          0.221255
# 819         819  0.503158  0.305509          0.509839          0.292243
# 121         121  0.479754  0.396546          0.488677          0.382778
# 340         340  0.531637  0.241956          0.541983          0.223023
#
#      LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  \
# 807    0.464322    0.210967          0.471160          0.210729
# 206    0.563689    0.150870          0.569317          0.151043
# 61     0.529458    0.154888          0.534632          0.156282
# 168    0.536439    0.228212          0.543112          0.228159
# 423    0.544985    0.292686          0.549073          0.293862
# 120    0.566951    0.264043          0.572605          0.264838
# 757    0.533574    0.220723          0.538540          0.220232
# 819    0.514121    0.293342          0.517238          0.294543
# 121    0.494061    0.383315          0.498273          0.384015
# 340    0.548247    0.222328          0.554601          0.221983
#
#      RIGHT_EYE_INNER_X  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# 807           0.444262  ...     0.526893     1.178501      0.436604
# 206           0.538292  ...     0.587085     1.155008      0.488647
# 61            0.508343  ...     0.568905     1.141174      0.475758
# 168           0.508525  ...     0.564756     1.079453      0.476928
# 423           0.525937  ...     0.562611     0.991069      0.471130
# 120           0.541099  ...     0.565003     1.107331      0.526012
# 757           0.522753  ...     0.623209     1.167931      0.529411
# 819           0.495969  ...     0.558184     0.989516      0.476565
# 121           0.473753  ...     0.507578     1.097907      0.453860
# 340           0.523297  ...     0.585398     1.099185      0.501236
#
#      RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# 807      1.156657           0.513379           1.232289            0.407984
# 206      1.126244           0.607392           1.201516            0.479650
# 61       1.119473           0.583227           1.182017            0.456666
# 168      1.102690           0.581390           1.135506            0.452568
# 423      0.995401           0.575249           1.043437            0.470304
# 120      1.079174           0.571408           1.156310            0.525020
# 757      1.172765           0.595707           1.210718            0.505257
# 819      1.014751           0.582603           1.030495            0.474320
# 121      1.061219           0.507551           1.148666            0.447908
# 340      1.106249           0.580852           1.158608            0.481548
#
#      RIGHT_FOOT_INDEX_Y  id  action
# 807            1.207668   8       6
# 206            1.180475   9       1
# 61             1.172234   5       7
# 168            1.155008   5       1
# 423            1.053313   9       4
# 120            1.145182  10       7
# 757            1.212255   4       6
# 819            1.062899   0       3
# 121            1.114921   0       1
# 340            1.155476   0       4
#
# [10 rows x 69 columns]

# %%
df_move.describe()
# Out:
#        Unnamed: 0      NOSE_X      NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# count  925.000000  925.000000  925.000000        925.000000        925.000000
# mean   462.000000    0.521023    0.234959          0.528936          0.216360
# std    267.168798    0.036173    0.065146          0.035798          0.066789
# min      0.000000    0.368753    0.065539          0.376457          0.040086
# 25%    231.000000    0.497712    0.177127          0.506219          0.159184
# 50%    462.000000    0.523055    0.235238          0.530997          0.217281
# 75%    693.000000    0.543585    0.272061          0.551770          0.251400
# max    924.000000    0.626652    0.459050          0.637184          0.447650
#
#        LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  \
# count  925.000000  925.000000        925.000000        925.000000
# mean     0.534079    0.216729          0.538965          0.217212
# std      0.035720    0.066741          0.035669          0.066688
# min      0.382560    0.041456          0.389298          0.043240
# 25%      0.511896    0.160502          0.517164          0.161107
# 50%      0.536439    0.217126          0.541432          0.217169
# 75%      0.557469    0.250479          0.562783          0.250812
# max      0.641526    0.448985          0.647023          0.450590
#
#        RIGHT_EYE_INNER_X  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# count         925.000000  ...   925.000000   925.000000    925.000000
# mean            0.512999  ...     0.559436     1.112404      0.479615
# std             0.035850  ...     0.043686     0.055789      0.046555
# min             0.361336  ...     0.431566     0.875916      0.338722
# 25%             0.489277  ...     0.529070     1.088703      0.453860
# 50%             0.515329  ...     0.566490     1.120180      0.481779
# 75%             0.534335  ...     0.589971     1.152558      0.505491
# max             0.620750  ...     0.688446     1.292897      0.624437
#
#        RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# count    925.000000         925.000000         925.000000          925.000000
# mean       1.108786           0.568380           1.161415            0.476033
# std        0.049936           0.039665           0.054793            0.043041
# min        0.851541           0.443042           0.946031            0.343203
# 25%        1.086766           0.538883           1.134547            0.453236
# 50%        1.115252           0.575753           1.168892            0.478506
# 75%        1.141223           0.596878           1.201502            0.504554
# max        1.289880           0.708857           1.365825            0.600779
#
#        RIGHT_FOOT_INDEX_Y          id      action
# count          925.000000  925.000000  925.000000
# mean             1.160251    4.618378    4.647568
# std              0.046934    3.042678    2.311066
# min              0.931781    0.000000    1.000000
# 25%              1.139047    2.000000    3.000000
# 50%              1.165547    5.000000    5.000000
# 75%              1.190257    7.000000    7.000000
# max              1.360272   10.000000    8.000000
#
# [8 rows x 69 columns]

# %%
df_speed.sample(10)
# Out:
#      Unnamed: 0    NOSE_X    NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# 126         126  0.573310  0.219369          0.583919          0.197441
# 215         215  0.504350  0.337028          0.510469          0.312362
# 39           39  0.545452  0.184332          0.552428          0.164530
# 64           64  0.548371  0.281698          0.557800          0.273006
# 247         247  0.504772  0.293114          0.507130          0.273942
# 235         235  0.397857  0.114144          0.400102          0.091766
# 118         118  0.489828  0.379147          0.497887          0.366310
# 167         167  0.522885  0.222779          0.531065          0.205034
# 45           45  0.512571  0.375831          0.522385          0.371747
# 110         110  0.534345  0.214620          0.542980          0.201204
#
#      LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  \
# 126    0.589778    0.198214          0.595590          0.199072
# 215    0.517340    0.308776          0.523938          0.304634
# 39     0.558766    0.164875          0.564210          0.165494
# 64     0.562315    0.275513          0.566428          0.278116
# 247    0.511746    0.270248          0.516745          0.266664
# 235    0.405781    0.087728          0.412119          0.084723
# 118    0.502191    0.366872          0.507170          0.367818
# 167    0.537130    0.206123          0.542819          0.207519
# 45     0.525864    0.375497          0.529264          0.379105
# 110    0.549318    0.202096          0.555256          0.203196
#
#      RIGHT_EYE_INNER_X  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# 126           0.565090  ...     0.616224     1.042570      0.555623
# 215           0.493315  ...     0.575072     1.169403      0.502998
# 39            0.534411  ...     0.588580     1.140837      0.513225
# 64            0.544002  ...     0.575850     1.053173      0.501315
# 247           0.495025  ...     0.583306     0.981560      0.505425
# 235           0.383682  ...     0.518164     1.192138      0.362916
# 118           0.483257  ...     0.512649     1.104823      0.445595
# 167           0.514089  ...     0.584302     1.106566      0.489682
# 45            0.511521  ...     0.514169     1.112014      0.448914
# 110           0.525217  ...     0.592062     1.104813      0.513877
#
#      RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# 126      1.062394           0.619181           1.083191            0.534252
# 215      1.161896           0.571565           1.222328            0.505581
# 39       1.131476           0.586092           1.200913            0.503444
# 64       1.051930           0.599971           1.103542            0.501617
# 247      0.995452           0.605878           1.091235            0.496543
# 235      1.187317           0.525828           1.255512            0.356214
# 118      1.084027           0.521832           1.144415            0.443433
# 167      1.121746           0.590799           1.174853            0.483894
# 45       1.091215           0.511582           1.162980            0.439623
# 110      1.103531           0.600235           1.148524            0.504371
#
#      RIGHT_FOOT_INDEX_Y  id  vitesse
# 126            1.115165   3        2
# 215            1.221682   2        1
# 39             1.178719   4        3
# 64             1.101540   7        3
# 247            1.108894   6        1
# 235            1.252730   5        1
# 118            1.133151   2        2
# 167            1.172944   8        2
# 45             1.131462   5        3
# 110            1.151430   1        2
#
# [10 rows x 69 columns]

# %%
df_speed.describe()
# Out:
#        Unnamed: 0      NOSE_X      NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# count  288.000000  288.000000  288.000000        288.000000        288.000000
# mean   143.500000    0.529386    0.235372          0.536791          0.218874
# std     83.282651    0.048314    0.066396          0.049233          0.066629
# min      0.000000    0.244219    0.075940          0.286611          0.049139
# 25%     71.750000    0.501793    0.186383          0.504420          0.169486
# 50%    143.500000    0.530995    0.225184          0.539624          0.208554
# 75%    215.250000    0.569700    0.270265          0.578657          0.256357
# max    287.000000    0.625534    0.541200          0.635065          0.445679
#
#        LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  \
# count  288.000000  288.000000        288.000000        288.000000
# mean     0.542048    0.219125          0.547169          0.219481
# std      0.048674    0.066534          0.048114          0.066516
# min      0.312500    0.050210          0.332831          0.051898
# 25%      0.509554    0.169836          0.514294          0.171174
# 50%      0.545720    0.209332          0.551326          0.210130
# 75%      0.583164    0.257260          0.587991          0.258283
# max      0.638274    0.438926          0.641407          0.433417
#
#        RIGHT_EYE_INNER_X  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# count         288.000000  ...   288.000000   288.000000    288.000000
# mean            0.520777  ...     0.574793     1.120130      0.488805
# std             0.050618  ...     0.037712     0.141008      0.050152
# min             0.202262  ...     0.441575     0.974134      0.192004
# 25%             0.490989  ...     0.561614     1.088926      0.474583
# 50%             0.521393  ...     0.587347     1.112304      0.493460
# 75%             0.562703  ...     0.593636     1.135531      0.514592
# max             0.622918  ...     0.641548     3.376222      0.577150
#
#        RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# count    288.000000         288.000000         288.000000          288.000000
# mean       1.115624           0.583112           1.177812            0.482100
# std        0.140584           0.039563           0.145022            0.048169
# min        0.978058           0.452663           1.066861            0.245334
# 25%        1.085628           0.572018           1.141441            0.474901
# 50%        1.104124           0.593448           1.171655            0.490636
# 75%        1.129060           0.610410           1.193562            0.504424
# max        3.380590           0.653649           3.503165            0.574057
#
#        RIGHT_FOOT_INDEX_Y          id     vitesse
# count          288.000000  288.000000  288.000000
# mean             1.171193    5.107639    2.003472
# std              0.143737    3.198248    0.828492
# min              1.082704    0.000000    1.000000
# 25%              1.138836    2.000000    1.000000
# 50%              1.158465    5.000000    2.000000
# 75%              1.179598    8.000000    3.000000
# max              3.499207   10.000000    3.000000
#
# [8 rows x 69 columns]

# %% [markdown]
# ## Remove unused columns

# %%
df_move.drop("Unnamed: 0", axis=1, inplace=True)
df_speed.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df_move.head()
# Out:
#      NOSE_X    NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  LEFT_EYE_X  \
# 0  0.527483  0.233743          0.537547          0.221841    0.543514
# 1  0.529460  0.232399          0.539147          0.219388    0.544955
# 2  0.535710  0.227969          0.544658          0.213441    0.549961
# 3  0.532217  0.231721          0.541330          0.218340    0.547114
# 4  0.530893  0.230663          0.540788          0.216573    0.546599
#
#    LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  RIGHT_EYE_INNER_X  \
# 0    0.222451          0.548894          0.222667           0.518267
# 1    0.220044          0.550169          0.220451           0.519817
# 2    0.214099          0.555203          0.214609           0.526447
# 3    0.218729          0.552475          0.218936           0.521476
# 4    0.216987          0.552033          0.217371           0.521106
#
#    RIGHT_EYE_INNER_Y  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# 0           0.223195  ...     0.568984     1.099623      0.500112
# 1           0.220597  ...     0.572888     1.098569      0.500650
# 2           0.213697  ...     0.569198     1.103799      0.502070
# 3           0.220155  ...     0.572534     1.101104      0.501038
# 4           0.216741  ...     0.571495     1.099096      0.502470
#
#    RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# 0      1.094744           0.581870           1.136647            0.496653
# 1      1.092846           0.586301           1.135108            0.497610
# 2      1.091973           0.583978           1.138893            0.498719
# 3      1.090957           0.585541           1.138233            0.499131
# 4      1.092658           0.585027           1.131527            0.496962
#
#    RIGHT_FOOT_INDEX_Y  id  action
# 0            1.141364   0       7
# 1            1.141453   0       7
# 2            1.142476   0       7
# 3            1.139777   0       7
# 4            1.141240   0       7
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Looking for duplicates

# %%
df_move[df_move.duplicated()]
# Out:
# Empty DataFrame
# Columns: [NOSE_X, NOSE_Y, LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, LEFT_EAR_X, LEFT_EAR_Y, RIGHT_EAR_X, RIGHT_EAR_Y, MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_RIGHT_X, MOUTH_RIGHT_Y, LEFT_SHOULDER_X, LEFT_SHOULDER_Y, RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, LEFT_ELBOW_X, LEFT_ELBOW_Y, RIGHT_ELBOW_X, RIGHT_ELBOW_Y, LEFT_WRIST_X, LEFT_WRIST_Y, RIGHT_WRIST_X, RIGHT_WRIST_Y, LEFT_PINKY_X, LEFT_PINKY_Y, RIGHT_PINKY_X, RIGHT_PINKY_Y, LEFT_INDEX_X, LEFT_INDEX_Y, RIGHT_INDEX_X, RIGHT_INDEX_Y, LEFT_THUMB_X, LEFT_THUMB_Y, RIGHT_THUMB_X, RIGHT_THUMB_Y, LEFT_HIP_X, LEFT_HIP_Y, RIGHT_HIP_X, RIGHT_HIP_Y, LEFT_KNEE_X, LEFT_KNEE_Y, RIGHT_KNEE_X, RIGHT_KNEE_Y, LEFT_ANKLE_X, LEFT_ANKLE_Y, RIGHT_ANKLE_X, RIGHT_ANKLE_Y, LEFT_HEEL_X, LEFT_HEEL_Y, RIGHT_HEEL_X, RIGHT_HEEL_Y, LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, id, action]
# Index: []
#
# [0 rows x 68 columns]

# %%
df_speed[df_speed.duplicated()]
# Out:
# Empty DataFrame
# Columns: [NOSE_X, NOSE_Y, LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, LEFT_EAR_X, LEFT_EAR_Y, RIGHT_EAR_X, RIGHT_EAR_Y, MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_RIGHT_X, MOUTH_RIGHT_Y, LEFT_SHOULDER_X, LEFT_SHOULDER_Y, RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, LEFT_ELBOW_X, LEFT_ELBOW_Y, RIGHT_ELBOW_X, RIGHT_ELBOW_Y, LEFT_WRIST_X, LEFT_WRIST_Y, RIGHT_WRIST_X, RIGHT_WRIST_Y, LEFT_PINKY_X, LEFT_PINKY_Y, RIGHT_PINKY_X, RIGHT_PINKY_Y, LEFT_INDEX_X, LEFT_INDEX_Y, RIGHT_INDEX_X, RIGHT_INDEX_Y, LEFT_THUMB_X, LEFT_THUMB_Y, RIGHT_THUMB_X, RIGHT_THUMB_Y, LEFT_HIP_X, LEFT_HIP_Y, RIGHT_HIP_X, RIGHT_HIP_Y, LEFT_KNEE_X, LEFT_KNEE_Y, RIGHT_KNEE_X, RIGHT_KNEE_Y, LEFT_ANKLE_X, LEFT_ANKLE_Y, RIGHT_ANKLE_X, RIGHT_ANKLE_Y, LEFT_HEEL_X, LEFT_HEEL_Y, RIGHT_HEEL_X, RIGHT_HEEL_Y, LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, id, vitesse]
# Index: []
#
# [0 rows x 68 columns]

# %% [markdown]
# ## Normalisation
#
# La normalisation est effectué avant la sélection des colonnes, car certaines variables qui seront supprimées sont utilisées pour la normalisation.

# %%
test = normalize(df_move)
test
# Out:
#        NOSE_X    NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  LEFT_EYE_X  \
# 0   -0.189520 -1.312901         -0.155421         -1.353228   -0.135203
# 1   -0.182254 -1.314551         -0.149360         -1.358730   -0.129638
# 2   -0.158476 -1.322949         -0.128436         -1.371728   -0.110630
# 3   -0.170368 -1.315287         -0.139673         -1.360352   -0.120193
# 4   -0.174467 -1.316722         -0.141264         -1.364005   -0.121763
# ..        ...       ...               ...               ...         ...
# 920 -0.251434 -1.353673         -0.222257         -1.417592   -0.203978
# 921 -0.232133 -1.392175         -0.199478         -1.448945   -0.181524
# 922 -0.220981 -1.382572         -0.196004         -1.440485   -0.179323
# 923 -0.206766 -1.399031         -0.177826         -1.455258   -0.161849
# 924 -0.160695 -1.399816         -0.131767         -1.449128   -0.114355
#
#      LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  RIGHT_EYE_INNER_X  \
# 0     -1.351162         -0.116976         -1.350431          -0.220749
# 1     -1.356506         -0.111934         -1.355123          -0.215001
# 2     -1.369519         -0.093031         -1.367806          -0.189579
# 3     -1.359044         -0.102137         -1.358345          -0.206542
# 4     -1.362615         -0.103529         -1.361328          -0.207310
# ..          ...               ...               ...                ...
# 920   -1.416921         -0.186207         -1.415424          -0.276890
# 921   -1.444824         -0.163144         -1.440136          -0.259163
# 922   -1.436509         -0.163772         -1.431149          -0.248824
# 923   -1.449959         -0.144331         -1.444409          -0.226568
# 924   -1.443221         -0.098014         -1.437688          -0.190537
#
#      RIGHT_EYE_INNER_Y  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# 0            -1.348641  ...    -0.048905     1.620948     -0.282262
# 1            -1.354627  ...    -0.034786     1.626694     -0.280087
# 2            -1.370867  ...    -0.046043     1.617568     -0.271421
# 3            -1.354240  ...    -0.034576     1.612841     -0.275378
# 4            -1.363441  ...    -0.038219     1.597534     -0.269849
# ..                 ...  ...          ...          ...           ...
# 920          -1.412880  ...    -0.030094     1.470932     -0.359615
# 921          -1.453696  ...    -0.060868     1.505645     -0.339659
# 922          -1.444414  ...     0.029887     1.488251     -0.325016
# 923          -1.465146  ...     0.021381     1.642350     -0.345450
# 924          -1.464992  ...    -0.109704     1.493864     -0.406448
#
#      RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# 0        1.604416          -0.005242           1.874501           -0.293984
# 1        1.607263           0.010758           1.874340           -0.290407
# 2        1.577862           0.003579           1.866654           -0.282670
# 3        1.578665           0.009230           1.870725           -0.281802
# 4        1.575930           0.007194           1.841117           -0.288334
# ..            ...                ...                ...                 ...
# 920      1.568869           0.014148           1.599912           -0.353482
# 921      1.537680          -0.030568           1.632727           -0.376062
# 922      1.594214           0.089486           1.642447           -0.315986
# 923      1.742162           0.036409           1.858709           -0.323316
# 924      1.606833          -0.053956           1.532238           -0.432482
#
#      RIGHT_FOOT_INDEX_Y    id  action
# 0              1.890484   0.0     7.0
# 1              1.895883   0.0     7.0
# 2              1.878682   0.0     7.0
# 3              1.875928   0.0     7.0
# 4              1.873711   0.0     7.0
# ..                  ...   ...     ...
# 920            1.728665  10.0     3.0
# 921            1.709573  10.0     3.0
# 922            1.771576  10.0     3.0
# 923            1.928060  10.0     3.0
# 924            1.693905  10.0     3.0
#
# [925 rows x 68 columns]

# %%
test.describe()
# Out:
#            NOSE_X      NOSE_Y  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  LEFT_EYE_X  \
# count  925.000000  925.000000        925.000000        925.000000  925.000000
# mean    -0.138610   -1.336016         -0.113782         -1.394266   -0.097627
# std      0.078280    0.064192          0.072322          0.063117    0.069821
# min     -0.421909   -1.555785         -0.411632         -1.615338   -0.391764
# 25%     -0.179239   -1.382142         -0.151594         -1.441253   -0.133781
# 50%     -0.155356   -1.338809         -0.125956         -1.395458   -0.108197
# 75%     -0.114922   -1.291950         -0.087685         -1.349112   -0.068713
# max      0.549295   -1.045668          0.553197         -1.115127    0.556614
#
#        LEFT_EYE_Y  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  RIGHT_EYE_INNER_X  \
# count  925.000000        925.000000        925.000000         925.000000
# mean    -1.393060         -0.082314         -1.391490          -0.163985
# std      0.062133          0.067446          0.061157           0.077602
# min     -1.608010         -0.373486         -1.599654          -0.457028
# 25%     -1.438511         -0.116976         -1.437688          -0.207097
# 50%     -1.394142         -0.091148         -1.392554          -0.178693
# 75%     -1.349473         -0.053184         -1.347779          -0.137426
# max     -1.119787          0.559509         -1.124909           0.525234
#
#        RIGHT_EYE_INNER_Y  ...  LEFT_HEEL_X  LEFT_HEEL_Y  RIGHT_HEEL_X  \
# count         925.000000  ...   925.000000   925.000000    925.000000
# mean           -1.394976  ...    -0.019544     1.424579     -0.269138
# std             0.065212  ...     0.072458     0.134969      0.095994
# min            -1.631622  ...    -0.261251     0.883097     -0.474277
# 25%            -1.444329  ...    -0.059716     1.332175     -0.330301
# 50%            -1.395223  ...    -0.015803     1.424507     -0.282262
# 75%            -1.345987  ...     0.021381     1.519477     -0.224357
# max            -1.112506  ...     0.194410     1.831249      0.369370
#
#        RIGHT_HEEL_Y  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_X  \
# count    925.000000         925.000000         925.000000          925.000000
# mean       1.413970           0.009848           1.887857           -0.279263
# std        0.135589           0.064197           0.243205            0.095643
# min        0.769816          -0.434611           1.331246           -0.532376
# 25%        1.323322          -0.033079           1.734909           -0.338771
# 50%        1.414360           0.007841           1.843813           -0.288858
# 75%        1.508599           0.049852           1.961164           -0.227340
# max        1.784392           0.350257           2.989409            0.393423
#
#        RIGHT_FOOT_INDEX_Y          id      action
# count          925.000000  925.000000  925.000000
# mean             1.885693    4.618378    4.647568
# std              0.231239    3.042678    2.311066
# min              1.398340    0.000000    1.000000
# 25%              1.732386    2.000000    3.000000
# 50%              1.837899    5.000000    5.000000
# 75%              1.972416    7.000000    7.000000
# max              2.762729   10.000000    8.000000
#
# [8 rows x 68 columns]

# %% [markdown]
# ### Selection des colonnes (manuellement, par déduction)

# %%
test.columns()
# Out:
# Index(['NOSE_X', 'NOSE_Y', 'LEFT_EYE_INNER_X', 'LEFT_EYE_INNER_Y',
#        'LEFT_EYE_X', 'LEFT_EYE_Y', 'LEFT_EYE_OUTER_X', 'LEFT_EYE_OUTER_Y',
#        'RIGHT_EYE_INNER_X', 'RIGHT_EYE_INNER_Y', 'RIGHT_EYE_X', 'RIGHT_EYE_Y',
#        'RIGHT_EYE_OUTER_X', 'RIGHT_EYE_OUTER_Y', 'LEFT_EAR_X', 'LEFT_EAR_Y',
#        'RIGHT_EAR_X', 'RIGHT_EAR_Y', 'MOUTH_LEFT_X', 'MOUTH_LEFT_Y',
#        'MOUTH_RIGHT_X', 'MOUTH_RIGHT_Y', 'LEFT_SHOULDER_X', 'LEFT_SHOULDER_Y',
#        'RIGHT_SHOULDER_X', 'RIGHT_SHOULDER_Y', 'LEFT_ELBOW_X', 'LEFT_ELBOW_Y',
#        'RIGHT_ELBOW_X', 'RIGHT_ELBOW_Y', 'LEFT_WRIST_X', 'LEFT_WRIST_Y',
#        'RIGHT_WRIST_X', 'RIGHT_WRIST_Y', 'LEFT_PINKY_X', 'LEFT_PINKY_Y',
#        'RIGHT_PINKY_X', 'RIGHT_PINKY_Y', 'LEFT_INDEX_X', 'LEFT_INDEX_Y',
#        'RIGHT_INDEX_X', 'RIGHT_INDEX_Y', 'LEFT_THUMB_X', 'LEFT_THUMB_Y',
#        'RIGHT_THUMB_X', 'RIGHT_THUMB_Y', 'LEFT_HIP_X', 'LEFT_HIP_Y',
#        'RIGHT_HIP_X', 'RIGHT_HIP_Y', 'LEFT_KNEE_X', 'LEFT_KNEE_Y',
#        'RIGHT_KNEE_X', 'RIGHT_KNEE_Y', 'LEFT_ANKLE_X', 'LEFT_ANKLE_Y',
#        'RIGHT_ANKLE_X', 'RIGHT_ANKLE_Y', 'LEFT_HEEL_X', 'LEFT_HEEL_Y',
#        'RIGHT_HEEL_X', 'RIGHT_HEEL_Y', 'LEFT_FOOT_INDEX_X',
#        'LEFT_FOOT_INDEX_Y', 'RIGHT_FOOT_INDEX_X', 'RIGHT_FOOT_INDEX_Y', 'id',
#        'action'],
#       dtype='object')

# %%
list_move = [
    "NOSE_X", "NOSE_Y",
    "LEFT_EYE_INNER_X", "LEFT_EYE_INNER_Y",
    "LEFT_EYE_X", "LEFT_EYE_Y",
    "LEFT_EYE_OUTER_X", "LEFT_EYE_OUTER_Y",
    "RIGHT_EYE_INNER_X", "RIGHT_EYE_INNER_Y",
    "RIGHT_EYE_X", "RIGHT_EYE_Y",
    "RIGHT_EYE_OUTER_X", "RIGHT_EYE_OUTER_Y",
    "LEFT_EAR_X", "LEFT_EAR_Y",
    "RIGHT_EAR_X", "RIGHT_EAR_Y",
    "MOUTH_LEFT_X", "MOUTH_LEFT_Y",
    "MOUTH_RIGHT_X", "MOUTH_RIGHT_Y",
    "LEFT_SHOULDER_X", "LEFT_SHOULDER_Y",
    "RIGHT_SHOULDER_X", "RIGHT_SHOULDER_Y",
]

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ## PCA
